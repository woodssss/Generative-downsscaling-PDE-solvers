# %% [markdown]
# # Example of 2D nonlinear Poisson (8 times superesolution).

# %% [markdown]
# # Consider -0.0005 \Delta u + u^3 = a, a~N(0, (-\Delta + 49I)-\alpha).

# %%
## Training data and testing data by following code (the data for this example is available in data folder).
# %run gen_P_2d.py -ns 100 -nex 40 -nx 16 -m 8 -d0 -0.0005 -d1 1 -d2 1 -alp 1.6 -tau 7 -flg 1 -seed 9
# %run gen_P_2d.py -ns 30 -nex 20 -nx 16 -m 8 -d0 -0.0005 -d1 1 -d2 1 -alp 1.6 -tau 7 -flg 2 -seed 25

# %% [markdown]
# # Model training and prediction
# ## The configuration of the diffusion model and the FNO are defined in the config_2D.py, one may modify it.

# %% [markdown]
# ## Train DDPM

# %%
# %run main_2D.py

# %% [markdown]
# ## Train FNO

# %%
# %run FNO_2D.py

# %% [markdown]
# ## Compare all solvers (CSI, FNO, DDPM, DDIM and theirs fine tune)
# ### Following example use 30 training data and perform on 30 testing data.

# %%
# %run Solver_2D.py
# Out:
# In test example, we clip at : 0.931165, avg time for coarse solver are: 0.058827, for fine solver are: 7.789899, for ref solver are: 122.345167
# UNet num of parameters 17337730
# compute time of coarse solver is: 0.058827, fine solver is: 7.789899, FNO is: 0.015758, ddpm is: 9.407514, ddim is: 1.918944
# compute time of coarse+ft is is: 0.552153, FNO+ft is: 0.509083, PGDM is: 2.412269
# Relative L2 error of coarse solver is: 0.277053, fine solver is: 0.003484, FNO is: 0.177735, ddpm is: 0.083851, ddim is: 0.090454
# Relative L2 error of coarse solver + ft is: 0.056453, fine solver is: 0.003484, FNO + ft is: 0.027778, PGDM is: 0.006302
